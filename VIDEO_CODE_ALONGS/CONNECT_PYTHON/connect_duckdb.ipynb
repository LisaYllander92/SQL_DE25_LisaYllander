# %% [markdown]
# # Connect duckdb

# %%
import duckdb

with duckdb.connect("databases/hotels.duckdb") as conn:
    
    conn.sql("""
    CREATE OR REPLACE TABLE bookings (
        date DATE,
        room_type STRING,
        price FLOAT,
        breakfast BOOLEAN,
        name STRING,
        email STRING,
        guests UINT8
    );
    """)

    conn.sql("""
    INSERT INTO bookings VALUES
        ('2024-01-15', 'Single', 150.00, True, 'John Doe', 'john@email.com', 2),
        ('2024-01-16', 'Double', 220.00, False, 'Jane Smith', 'jane@email.com', 3),
        ('2024-01-17', 'Suite', 450.00, True, 'Bob Johnson', 'bob@email.com', 1),
        ('2024-01-18', 'Single', 150.00, True, 'Alice Brown', 'alice@email.com', 1),
        ('2024-01-19', 'Double', 220.00, True, 'Charlie Davis', 'charlie@email.com', 4),
        ('2024-01-20', 'Suite', 450.00, False, 'Eva Wilson', 'eva@email.com', 2),
        ('2024-01-21', 'Single', 150.00, False, 'Frank Miller', 'frank@email.com', 1),
        ('2024-01-22', 'Double', 220.00, True, 'Grace Lee', 'grace@email.com', 3);
    """)

    bookings = conn.sql("FROM bookings;").df()

bookings
# Out:
#         date room_type  price  breakfast           name              email  \
# 0 2024-01-15    Single  150.0       True       John Doe     john@email.com
# 1 2024-01-16    Double  220.0      False     Jane Smith     jane@email.com
# 2 2024-01-17     Suite  450.0       True    Bob Johnson      bob@email.com
# 3 2024-01-18    Single  150.0       True    Alice Brown    alice@email.com
# 4 2024-01-19    Double  220.0       True  Charlie Davis  charlie@email.com
# 5 2024-01-20     Suite  450.0      False     Eva Wilson      eva@email.com
# 6 2024-01-21    Single  150.0      False   Frank Miller    frank@email.com
# 7 2024-01-22    Double  220.0       True      Grace Lee    grace@email.com
#
#    guests
# 0       2
# 1       3
# 2       1
# 3       1
# 4       4
# 5       2
# 6       1
# 7       3

# %%
bookings.head
# Out:
# <bound method NDFrame.head of         date room_type  price  breakfast           name              email  \
# 0 2024-01-15    Single  150.0       True       John Doe     john@email.com
# 1 2024-01-16    Double  220.0      False     Jane Smith     jane@email.com
# 2 2024-01-17     Suite  450.0       True    Bob Johnson      bob@email.com
# 3 2024-01-18    Single  150.0       True    Alice Brown    alice@email.com
# 4 2024-01-19    Double  220.0       True  Charlie Davis  charlie@email.com
# 5 2024-01-20     Suite  450.0      False     Eva Wilson      eva@email.com
# 6 2024-01-21    Single  150.0      False   Frank Miller    frank@email.com
# 7 2024-01-22    Double  220.0       True      Grace Lee    grace@email.com
#
#    guests
# 0       2
# 1       3
# 2       1
# 3       1
# 4       4
# 5       2
# 6       1
# 7       3  >

# %%
bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       8 non-null      datetime64[us]
#  1   room_type  8 non-null      object
#  2   price      8 non-null      float32
#  3   breakfast  8 non-null      bool
#  4   name       8 non-null      object
#  5   email      8 non-null      object
#  6   guests     8 non-null      uint8
# dtypes: bool(1), datetime64[us](1), float32(1), object(3), uint8(1)
# memory usage: 436.0+ bytes

# %% [markdown]
# ## Read csv file directly

# %%
invoice = duckdb.sql("""
    FROM 'data/Leverantorsfaktura202408.csv';
""").df()

invoice.head()
# Out:
#             Förvaltning                          Leverantör  \
# 0     Stadsmiljönämnden                      TRACK TEC GMBH
# 1  Kretslopp och Vatten  POLISMYNDIGHETEN I VÄSTRA GÖTALAND
# 2  Kretslopp och Vatten  POLISMYNDIGHETEN I VÄSTRA GÖTALAND
# 3  Kretslopp och Vatten  POLISMYNDIGHETEN I VÄSTRA GÖTALAND
# 4  Exploateringsnämnden  POLISMYNDIGHETEN I VÄSTRA GÖTALAND
#
#   Organisationsnummer  Verifikationsnummer  Konto  \
# 0       106/5727/0626           4001291513   4101
# 1          2021000076           5601378982   6185
# 2          2021000076           5601377374   6185
# 3          2021000076           5601378519   6185
# 4          2021000076           2001226894   7641
#
#                                   Kontotext Belopp exkl moms
# 0  Inköp anläggnings och underhållsmaterial     9 835 315,00
# 1                    Anläggningsentreprenad           870,00
# 2                    Anläggningsentreprenad           870,00
# 3                    Anläggningsentreprenad           870,00
# 4   Diverse skatter och offentliga avgifter         1 000,00

# %%
invoice.shape
# Out:
# (92989, 7)

# %%
finance = duckdb.sql(
    """
    FROM 'data/financial_data.csv';
"""
).df()
finance
# Out:
#    transaction_id       date             company transaction_type  \
# 0         TXN1000 2024-01-15  UnitedHealth Group       Investment
# 1         TXN1001 2024-12-22        Broadcom Inc          Expense
# 2         TXN1002 2024-10-11           Starbucks     Capital Gain
# 3         TXN1003 2024-09-30     Lockheed Martin         Dividend
# 4         TXN1004 2024-07-02            IBM Corp   Operating Cost
# 5         TXN1005 2024-12-24      Salesforce Inc     Capital Gain
# 6         TXN1006 2024-12-02   Johnson & Johnson          Revenue
# 7         TXN1007 2024-01-16          Merck & Co         Dividend
# 8         TXN1008 2024-05-17     Bank of America   Operating Cost
# 9         TXN1009 2024-04-30     PayPal Holdings         Dividend
# 10        TXN1010 2024-06-06     Bank of America          Revenue
# 11        TXN1011 2024-06-24          Ford Motor     Capital Gain
# 12        TXN1012 2024-07-11    Procter & Gamble   Operating Cost
# 13        TXN1013 2024-03-23     Lockheed Martin         Dividend
# 14        TXN1014 2024-07-23          Intel Corp       Investment
# 15        TXN1015 2024-12-20       Thermo Fisher       Investment
# 16        TXN1016 2024-05-21          Merck & Co   Operating Cost
# 17        TXN1017 2024-01-22         Netflix Inc       Investment
# 18        TXN1018 2024-07-25         Abbott Labs          Expense
# 19        TXN1019 2024-04-23    American Express   Operating Cost
# 20        TXN1020 2024-09-10            IBM Corp     Capital Gain
# 21        TXN1021 2024-08-17          Home Depot     Capital Gain
# 22        TXN1022 2024-05-08       Goldman Sachs          Revenue
# 23        TXN1023 2024-05-03    Costco Wholesale         Dividend
# 24        TXN1024 2024-02-23           Adobe Inc     Capital Gain
# 25        TXN1025 2024-06-30        Coca-Cola Co   Operating Cost
# 26        TXN1026 2024-02-22            IBM Corp         Dividend
# 27        TXN1027 2024-05-28         NVIDIA Corp          Revenue
# 28        TXN1028 2024-12-04          Ford Motor         Dividend
# 29        TXN1029 2024-09-30      Meta Platforms          Revenue
# 30        TXN1030 2024-11-01        Alphabet Inc          Expense
# 31        TXN1031 2024-10-10        Alphabet Inc   Operating Cost
# 32        TXN1032 2024-02-24       Thermo Fisher          Revenue
# 33        TXN1033 2024-04-26           Adobe Inc     Capital Gain
# 34        TXN1034 2024-01-08          Merck & Co          Revenue
# 35        TXN1035 2024-03-06          AbbVie Inc   Operating Cost
# 36        TXN1036 2024-01-16     Lockheed Martin          Expense
# 37        TXN1037 2024-02-23         Netflix Inc          Revenue
# 38        TXN1038 2024-07-21           Starbucks         Dividend
# 39        TXN1039 2024-09-28           Accenture         Dividend
# 40        TXN1040 2024-06-24         NVIDIA Corp         Dividend
# 41        TXN1041 2024-03-15    Costco Wholesale          Revenue
# 42        TXN1042 2024-04-22        Coca-Cola Co   Operating Cost
# 43        TXN1043 2024-03-24      Microsoft Corp     Capital Gain
# 44        TXN1044 2024-12-15         Oracle Corp     Capital Gain
# 45        TXN1045 2024-10-20           Boeing Co          Expense
# 46        TXN1046 2024-03-25     McDonald's Corp          Expense
# 47        TXN1047 2024-03-08    Costco Wholesale     Capital Gain
# 48        TXN1048 2024-02-29    American Express         Dividend
# 49        TXN1049 2024-10-13          Ford Motor          Expense
#
#           category     amount currency account_number  \
# 0        Marketing  498789.60      JPY       ACC90616
# 1   Administrative  407890.44      GBP       ACC72475
# 2       Operations  363927.61      USD       ACC26222
# 3              R&D  336378.01      EUR       ACC86805
# 4   Administrative  193284.51      GBP       ACC72617
# 5     Distribution  218933.78      USD       ACC83475
# 6               HR  106129.05      GBP       ACC99107
# 7               IT  322226.78      USD       ACC14055
# 8            Legal   56158.44      JPY       ACC43482
# 9    Manufacturing  216685.39      GBP       ACC79758
# 10  Administrative  233397.28      JPY       ACC22958
# 11   Manufacturing  428212.62      EUR       ACC33952
# 12       Marketing  487282.61      EUR       ACC55764
# 13             R&D  491855.47      USD       ACC71707
# 14           Legal  329320.08      GBP       ACC19166
# 15              HR   38462.77      USD       ACC54067
# 16    Distribution  322686.64      USD       ACC91224
# 17           Legal   59954.34      GBP       ACC46537
# 18    Distribution  177015.20      JPY       ACC48779
# 19    Distribution  149043.78      EUR       ACC40084
# 20              IT  209596.10      USD       ACC36337
# 21           Sales  195095.88      EUR       ACC49012
# 22           Legal  340533.02      GBP       ACC31167
# 23  Administrative  319744.89      USD       ACC40748
# 24           Sales  475751.61      USD       ACC14080
# 25              IT  402414.92      USD       ACC78673
# 26       Marketing  302765.69      USD       ACC54540
# 27             R&D  357020.59      GBP       ACC13813
# 28              HR   18908.85      EUR       ACC59998
# 29      Operations  263136.24      USD       ACC50083
# 30           Sales  178012.43      USD       ACC16140
# 31      Operations   23040.17      GBP       ACC31880
# 32       Marketing  145399.43      USD       ACC44464
# 33              IT  267947.92      EUR       ACC92446
# 34           Sales  114487.25      EUR       ACC98501
# 35              IT   70534.14      JPY       ACC47578
# 36      Operations  144382.02      GBP       ACC96645
# 37    Distribution  398509.11      GBP       ACC14957
# 38  Administrative  370290.03      EUR       ACC11897
# 39              HR  125982.25      JPY       ACC49737
# 40      Operations  363362.86      USD       ACC20971
# 41           Legal  122985.98      GBP       ACC21308
# 42      Operations  470569.43      EUR       ACC53116
# 43              HR   12192.54      USD       ACC81393
# 44           Legal   14552.51      JPY       ACC68350
# 45   Manufacturing  495605.85      USD       ACC94035
# 46           Sales  122715.53      JPY       ACC16825
# 47      Operations  410175.44      EUR       ACC67901
# 48      Operations  477612.19      JPY       ACC42618
# 49             R&D   38612.22      JPY       ACC24082
#
#                              description     status payment_method  \
# 0                     Q1 revenue for r&d  Completed          Check
# 1                 Q4 capital gain for it  Completed  Wire Transfer
# 2          Q3 expense for administrative    Pending            ACH
# 3            Q4 investment for marketing  Completed          Check
# 4            Q2 expense for distribution  Completed    Credit Card
# 5               Q4 expense for marketing  Completed          Check
# 6         Q1 dividend for administrative    Pending            ACH
# 7              Q4 revenue for operations  Completed    Credit Card
# 8                  Q3 dividend for legal  Completed         PayPal
# 9           Q2 dividend for distribution    Pending          Check
# 10          Q2 investment for operations  Completed  Wire Transfer
# 11                     Q4 revenue for hr  Completed          Check
# 12              Q1 operating cost for it  Completed  Wire Transfer
# 13              Q1 operating cost for hr  Completed            ACH
# 14           Q2 investment for marketing    Pending    Credit Card
# 15                  Q1 expense for sales  Completed    Credit Card
# 16    Q1 operating cost for distribution  Completed  Wire Transfer
# 17       Q1 investment for manufacturing  Completed  Wire Transfer
# 18        Q4 capital gain for operations  Completed         PayPal
# 19         Q2 capital gain for marketing  Completed  Wire Transfer
# 20           Q1 revenue for distribution  Completed    Credit Card
# 21                   Q1 dividend for r&d  Completed  Wire Transfer
# 22                  Q2 revenue for sales  Completed            ACH
# 23            Q4 dividend for operations  Completed    Credit Card
# 24  Q4 operating cost for administrative  Completed            ACH
# 25                   Q4 dividend for r&d  Completed         PayPal
# 26                    Q1 dividend for hr  Completed         PayPal
# 27    Q2 operating cost for distribution    Pending          Check
# 28                     Q3 revenue for it  Completed         PayPal
# 29      Q1 capital gain for distribution  Completed         PayPal
# 30  Q1 operating cost for administrative  Completed         PayPal
# 31                 Q1 dividend for sales    Pending            ACH
# 32           Q3 operating cost for sales    Pending    Credit Card
# 33         Q3 capital gain for marketing    Pending            ACH
# 34              Q4 operating cost for hr  Completed            ACH
# 35             Q4 capital gain for sales  Completed    Credit Card
# 36                    Q2 dividend for hr  Completed            ACH
# 37           Q4 investment for marketing  Completed            ACH
# 38              Q4 expense for marketing    Pending         PayPal
# 39                     Q2 expense for it  Completed  Wire Transfer
# 40                Q2 capital gain for hr    Pending            ACH
# 41          Q3 expense for manufacturing    Pending         PayPal
# 42                  Q3 investment for hr    Pending    Credit Card
# 43                  Q3 investment for hr  Completed         PayPal
# 44                  Q3 revenue for sales  Completed         PayPal
# 45              Q4 expense for marketing    Pending         PayPal
# 46               Q2 investment for sales    Pending    Credit Card
# 47                    Q3 expense for r&d  Completed          Check
# 48         Q3 dividend for manufacturing  Completed  Wire Transfer
# 49               Q1 capital gain for r&d  Completed            ACH
#
#     tax_amount  net_amount
# 0     15640.11   483149.49
# 1     25883.85   382006.59
# 2     24814.56   339113.05
# 3     46359.17   290018.84
# 4     41529.35   151755.16
# 5     16406.73   202527.05
# 6     32574.01    73555.04
# 7     39464.74   282762.04
# 8     26903.53    29254.91
# 9     17616.20   199069.19
# 10    20178.83   213218.45
# 11     1513.28   426699.34
# 12    34420.33   452862.28
# 13    19261.45   472594.02
# 14    46166.99   283153.09
# 15    48773.80   -10311.03
# 16     4039.34   318647.30
# 17    40729.58    19224.76
# 18     3101.37   173913.83
# 19    23973.01   125070.77
# 20     4568.94   205027.16
# 21    48548.34   146547.54
# 22    15143.44   325389.58
# 23     6120.32   313624.57
# 24    34162.41   441589.20
# 25     2044.43   400370.49
# 26     3142.52   299623.17
# 27    33608.65   323411.94
# 28    35925.91   -17017.06
# 29    38626.96   224509.28
# 30    40465.38   137547.05
# 31    20564.21     2475.96
# 32    27963.04   117436.39
# 33    30464.75   237483.17
# 34    13367.23   101120.02
# 35      513.57    70020.57
# 36    24735.63   119646.39
# 37     5198.71   393310.40
# 38    24907.35   345382.68
# 39    33751.45    92230.80
# 40    34581.95   328780.91
# 41    28759.29    94226.69
# 42    37650.26   432919.17
# 43    20757.88    -8565.34
# 44    14142.35      410.16
# 45    27942.19   467663.66
# 46    48443.30    74272.23
# 47    13971.73   396203.71
# 48     5191.08   472421.11
# 49    30538.00     8074.22

# %% [markdown]
# # Read several csv files and combine

# %%
bookings = duckdb.sql("""
    FROM 'data/hotel*.csv';
"""
).df()

bookings.head()
# Out:
#      booking_id       guest_name   check_in  check_out room_type  guests  \
# 0  H2025-01-001        Anna Berg 2025-01-05 2025-01-07  Standard       2
# 1  H2025-01-002    Johan Nilsson 2025-01-10 2025-01-11    Single       1
# 2  H2025-01-003       Sofia Lind 2025-01-14 2025-01-16    Deluxe       2
# 3  H2025-01-004    Erik Svensson 2025-01-20 2025-01-22  Standard       3
# 4  H2025-01-005  Maria Johansson 2025-01-27 2025-01-28    Single       1
#
#    price_sek_per_night  breakfast       source     status
# 0                 1150       True       Direct  Confirmed
# 1                  890      False  Booking.com  Confirmed
# 2                 1450       True      Expedia  Confirmed
# 3                 1250       True       Direct  Confirmed
# 4                  920      False   Hotels.com  Cancelled

# %%
bookings.tail()
# Out:
#       booking_id       guest_name   check_in  check_out room_type  guests  \
# 10  H2025-03-011       Maria Berg 2025-03-21 2025-03-22  Standard       3
# 11  H2025-03-012    Isak Axelsson 2025-03-15 2025-03-18    Single       1
# 12  H2025-03-013   Elin Håkansson 2025-03-12 2025-03-13  Standard       2
# 13  H2025-03-014  Elias Bengtsson 2025-03-08 2025-03-09    Single       2
# 14  H2025-03-015   Albin Lundberg 2025-03-01 2025-03-03    Single       1
#
#     price_sek_per_night  breakfast      source     status
# 10                 1250       True  Hotels.com  Confirmed
# 11                 1012       True      Direct  Confirmed
# 12                 1151       True      Direct  Cancelled
# 13                 1097       True  Hotels.com  Confirmed
# 14                 1027      False     Expedia  Confirmed

# %% [markdown]
# ## Read json data

# %%
duckdb.sql("FROM 'data/library.json';").df()
# Out:
#             name                                              books
# 0  Coolu Libraru  [{'id': 1, 'title': 'The Hitchhiker's Guide to...

# %% [markdown]
# ### unnesting

# %%
books_df = duckdb.sql(""" 
           SELECT
           l.name as library_name,
           UNNEST(l.books, max_depth := 2)
           FROM 'data/library.json' AS l;""").df()

books_df
# Out:
#     library_name  id                                 title  \
# 0  Coolu Libraru   1  The Hitchhiker's Guide to the Galaxy
# 1  Coolu Libraru   2                   Pride and Prejudice
# 2  Coolu Libraru   3                                  1984
# 3  Coolu Libraru   4                 To Kill a Mockingbird
# 4  Coolu Libraru   5                      The Great Gatsby
# 5  Coolu Libraru   6                             Moby Dick
# 6  Coolu Libraru   7                         War and Peace
# 7  Coolu Libraru   8                 The Lord of the Rings
# 8  Coolu Libraru   9                  Crime and Punishment
# 9  Coolu Libraru  10                           Don Quixote
#
#                 author  year
# 0        Douglas Adams  1979
# 1          Jane Austen  1813
# 2        George Orwell  1949
# 3           Harper Lee  1960
# 4  F. Scott Fitzgerald  1925
# 5      Herman Melville  1851
# 6          Leo Tolstoy  1869
# 7       J.R.R. Tolkien  1954
# 8    Fyodor Dostoevsky  1866
# 9  Miguel de Cervantes  1605

# %% [markdown]
# ### use cross join

# %%
duckdb.sql("""
    SELECT
        l.name,
        b
    FROM 'data/library.json' l
    CROSS JOIN UNNEST(l.books) b
""").df()
# Out:
#             name                                                  b
# 0  Coolu Libraru  {'unnest': {'id': 10, 'title': 'Don Quixote', ...
# 1  Coolu Libraru  {'unnest': {'id': 9, 'title': 'Crime and Punis...
# 2  Coolu Libraru  {'unnest': {'id': 8, 'title': 'The Lord of the...
# 3  Coolu Libraru  {'unnest': {'id': 7, 'title': 'War and Peace',...
# 4  Coolu Libraru  {'unnest': {'id': 6, 'title': 'Moby Dick', 'au...
# 5  Coolu Libraru  {'unnest': {'id': 5, 'title': 'The Great Gatsb...
# 6  Coolu Libraru  {'unnest': {'id': 4, 'title': 'To Kill a Mocki...
# 7  Coolu Libraru  {'unnest': {'id': 3, 'title': '1984', 'author'...
# 8  Coolu Libraru  {'unnest': {'id': 2, 'title': 'Pride and Preju...
# 9  Coolu Libraru  {'unnest': {'id': 1, 'title': 'The Hitchhiker'...

# %%
books_df = duckdb.sql("""
    SELECT
        l.name,
        b.unnest.title,
        b.unnest.author,
        b.unnest.year,
    FROM 'data/library.json' l
    CROSS JOIN UNNEST(l.books) b
""").df()

# %%
books_df
# Out:
#             name                                 title               author  \
# 0  Coolu Libraru                           Don Quixote  Miguel de Cervantes
# 1  Coolu Libraru                  Crime and Punishment    Fyodor Dostoevsky
# 2  Coolu Libraru                 The Lord of the Rings       J.R.R. Tolkien
# 3  Coolu Libraru                         War and Peace          Leo Tolstoy
# 4  Coolu Libraru                             Moby Dick      Herman Melville
# 5  Coolu Libraru                      The Great Gatsby  F. Scott Fitzgerald
# 6  Coolu Libraru                 To Kill a Mockingbird           Harper Lee
# 7  Coolu Libraru                                  1984        George Orwell
# 8  Coolu Libraru                   Pride and Prejudice          Jane Austen
# 9  Coolu Libraru  The Hitchhiker's Guide to the Galaxy        Douglas Adams
#
#    year
# 0  1605
# 1  1866
# 2  1954
# 3  1869
# 4  1851
# 5  1925
# 6  1960
# 7  1949
# 8  1813
# 9  1979

# %%
books_df.to_csv("data/books.csv", index = False) # create csv file
