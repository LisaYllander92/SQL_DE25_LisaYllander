# %% [markdown]
# ## DuckDB Python API
# - the same way of loading sakila data as via terminal

# %%
import duckdb
from pathlib import Path # without pathlib you need to delete everything

# %%
import pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\lisay\Documents\SQL_DE25_Lisa_Yllander\.venv\Lib\site-packages\pandas\__init__.py:38
#      36 try:
#      37     # numpy compat
# ---> 38     from pandas.compat import (
#      39         is_numpy_dev as _is_numpy_dev,  # pyright: ignore[reportUnusedImport] # noqa: F401
#      40     )
#      41 except ImportError as _err:  # pragma: no cover
#
# File c:\Users\lisay\Documents\SQL_DE25_Lisa_Yllander\.venv\Lib\site-packages\pandas\compat\__init__.py:28
#      27 import pandas.compat.compressors
# ---> 28 from pandas.compat.numpy import is_numpy_dev
#      29 from pandas.compat.pyarrow import (
#      30     HAS_PYARROW,
#      31     pa_version_under10p1,
#    (...)     41     pa_version_under21p0,
#      42 )
#
# File c:\Users\lisay\Documents\SQL_DE25_Lisa_Yllander\.venv\Lib\site-packages\pandas\compat\numpy\__init__.py:6
#       4 import numpy as np
# ----> 6 from pandas.util.version import Version
#       8 # numpy versioning
#
# ModuleNotFoundError: No module named 'pandas.util'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas
#
# File c:\Users\lisay\Documents\SQL_DE25_Lisa_Yllander\.venv\Lib\site-packages\pandas\__init__.py:43
#      41 except ImportError as _err:  # pragma: no cover
#      42     _module = _err.name
# ---> 43     raise ImportError(
#      44         f"C extension: {_module} not built. If you want to import "
#      45         "pandas from the source directory, you may need to run "
#      46         "'python setup.py build_ext' to build the C extensions first."
#      47     ) from _err
#      49 from pandas._config import (
#      50     get_option,
#      51     set_option,
#    (...)     55     options,
#      56 )
#      58 # let init-time option registration happen
#
# ImportError: C extension: pandas.util not built. If you want to import pandas from the source directory, you may need to run 'python setup.py build_ext' to build the C extensions first.

# %% [markdown]
# ### read data frame one by one

# %%
# create variable to store duckdb path
duckdb_path = "data/sakila.duckdb"
Path(duckdb_path).unlink(missing_ok=True) 

# connect to duckdb file with context manager,
# and ingest the data. 
# same as duckdb sakila.duckdb < sql/laod_sakila.sql
with duckdb.connect(duckdb_path) as conn, open("sql/load_sakila.sql") as ingest_scripts:
    conn.sql(ingest_scripts.read())
    # create pandas dataframes from the created duckdb connection
    description = conn.sql("DESC;").df()
    film = conn.sql("FROM film;").df()

# check the created dataframe
film.head(2)
# Out:
# ---------------------------------------------------------------------------
# InvalidInputException                     Traceback (most recent call last)
# Cell In[7], line 8
#       3 Path(duckdb_path).unlink(missing_ok=True)
#       5 # connect to duckdb file with context manager,
#       6 # and ingest the data.
#       7 # same as duckdb sakila.duckdb < sql/laod_sakila.sql
# ----> 8 with duckdb.connect(duckdb_path) as conn, open("sql/load_sakila.sql") as ingest_scripts:
#       9     conn.sql(ingest_scripts.read())
#      10     # create pandas dataframes from the created duckdb connection
#
# Cell In[7], line 11
#       9     conn.sql(ingest_scripts.read())
#      10     # create pandas dataframes from the created duckdb connection
# ---> 11     description = conn.sql("DESC;").df()
#      12     film = conn.sql("FROM film;").df()
#      14 # check the created dataframe
#
# InvalidInputException: Invalid Input Error: 'pandas' is required for this operation but it was not installed

# %%
description.head(3)
# Out:
#   database schema      name  \
# 0   sakila   main     actor
# 1   sakila   main   address
# 2   sakila   main  category
#
#                                         column_names  \
# 0     [actor_id, first_name, last_name, last_update]
# 1  [address_id, address, address2, district, city...
# 2                   [category_id, name, last_update]
#
#                                         column_types  temporary
# 0              [DOUBLE, VARCHAR, VARCHAR, TIMESTAMP]      False
# 1  [BIGINT, VARCHAR, VARCHAR, VARCHAR, BIGINT, VA...      False
# 2                       [BIGINT, VARCHAR, TIMESTAMP]      False

# %% [markdown]
# ### read all tables into dataframes

# %%
# create an empty dictionary to keep all dataframes
dfs = {}

with duckdb.connect(duckdb_path) as conn: 
    for name in description["name"]:
        dfs[name] = conn.sql(f"FROM {name};").df() # to store all dataframes from description by column 'name' into dictionary

# %%
# check the resulting dictionary
dfs.keys()
# Out:
# dict_keys(['actor', 'address', 'category', 'city', 'country', 'customer', 'customer_list', 'film', 'film_actor', 'film_category', 'film_list', 'film_text', 'inventory', 'language', 'payment', 'rental', 'sales_by_film_category', 'sales_by_store', 'staff', 'staff_list', 'store'])

# %%
# each value for each key in the dictionary is a panda dataframe
type(dfs["actor"])
# Out:
# pandas.core.frame.DataFrame

# %%
# check the content of the df
dfs["actor"].head(3)
# Out:
#    actor_id first_name last_name         last_update
# 0       1.0   PENELOPE   GUINESS 2021-03-06 15:51:59
# 1       2.0       NICK  WAHLBERG 2021-03-06 15:51:59
# 2       3.0         ED     CHASE 2021-03-06 15:51:59

# %% [markdown]
# ### register dfs to duckdb (tables) by joining dataframes

# %%
# duckdb.register("actor", dfs["actor"]) -one by one

# %% [markdown]
# ## join the register tables

# %%
table_names = ["film", "film_actor", "film_category", "actor", "category"]

for table_name in table_names:
    duckdb.register(table_name, dfs[table_name])

duckdb.sql("DESC;").df()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 table_names = ["film", "film_actor", "film_category", "actor", "category"]
#       3 for table_name in table_names:
# ----> 4     duckdb.register(table_name, dfs[table_name])
#       6 duckdb.sql("DESC;").df()
#
# NameError: name 'duckdb' is not defined

# %% [markdown]
# ## EDA with pandas
# - a light introduction of pandas

# %% [markdown]
# ## Visualization with pandas dataframe
